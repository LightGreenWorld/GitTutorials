# %%
import urllib.request
import pandas as pd

# %%
urllib.request.urlretrieve("https://raw.githubusercontent.com/LawrenceDuan/IMDb-Review-Analysis/master/IMDb_Reviews.csv", filename="IMDb_Reviews.csv")
# Out:
# ('IMDb_Reviews.csv', <http.client.HTTPMessage at 0x1d96b9f0518>)

# %%
df = pd.read_csv('IMDb_Reviews.csv', encoding='latin1')
df.head()
# Out:
#                                               review  sentiment
# 0  My family and I normally do not watch local mo...          1
# 1  Believe it or not, this was at one time the wo...          0
# 2  After some internet surfing, I found the "Home...          0
# 3  One of the most unheralded great works of anim...          1
# 4  It was the Sixties, and anyone with long hair ...          0

# %%
print('전체 샘플의 개수 : {}'.format(len(df)))
# Out:
# 전체 샘플의 개수 : 50000

# %%
from sklearn.model_selection import train_test_split

train_df, test_df = train_test_split(df, test_size=0.5, random_state=0)
train_df.shape, test_df.shape
# Out:
# ((25000, 2), (25000, 2))

# %%
train_df.to_csv("train_data.csv", index=False)
test_df.to_csv("test_data.csv", index=False)

# %%
#!pip install torchtext
from torchtext import data # torchtext.data 임포트

# %%
TEXT = data.Field(sequential=True,
                  use_vocab=True,
                  tokenize=str.split,
                  lower=True,
                  batch_first=True,
                  fix_length=150)

# %%
LABEL = data.Field(sequential=False,
                   use_vocab=False,
                   batch_first=False,
                   is_target=True)

# %%
from torchtext.data import TabularDataset

# %%
train_data, test_data = TabularDataset.splits(
        path='.', train='train_data.csv', test='test_data.csv', format='csv',
        fields=[('text', TEXT), ('label', LABEL)], skip_header=True)

# %%
print('훈련 샘플의 개수 : {}'.format(len(train_data)))
print('테스트 샘플의 개수 : {}'.format(len(test_data)))
# Out:
# 훈련 샘플의 개수 : 25000
# 테스트 샘플의 개수 : 25000

# %%
print(vars(train_data[0]))
# Out:
# {'text': ['this', 'movie', 'is', 'just', 'like', 'every', 'other', 'dutch', 'movie,', 'so', 'if', 'you', 'enjoy', 'movies', 'such', 'as', 'turks', 'fruit', 'and', 'de', 'kleine', 'blonde', 'dood.', 'then', 'you', 'might', 'be', 'okay', 'with', 'this', 'one', '(even', 'though', 'those', 'two', 'have', 'much', 'better', 'stories', 'and', 'actors)', 'zomerhitte', 'starts', 'strong', 'enough,', 'but', 'even', 'that', 'one', 'good', 'scene', 'ends', 'up', 'having', 'nothing', 'to', 'do', 'with', 'the', 'storyline.', "there's", 'a', 'lot', 'of', 'nudity', '(but', 'me', 'and', 'others', 'just', 'could', 'not', 'find', 'that', 'girl', 'attractive),', 'the', 'dialog', 'is', 'laughable', '(as', 'we', 'did', 'a', 'lot', 'to', 'the', 'annoyance', 'of', 'other', 'movie', 'watchers),', 'and', 'some', 'of', 'the', 'scenes', 'are', 'so', 'completely', 'random', 'that', 'this', 'is', 'more', 'of', 'an', 'unintentional', 'comedy', 'than', 'anything', 'else', '(like', 'a', 'random', 'scene', 'in', 'which', 'an', 'owl', 'rips', "somebody's", 'eye', 'out...it', 'has', 'nothing', 'to', 'do', 'with', 'anything', 'and', 'is', 'only', 'referenced', 'once', 'later', 'in', 'a', 'sentence', 'saying', '"did', 'you', 'hear', 'what', 'happened...i', 'was', 'there").', 'the', 'only', 'reason', 'i', 'gave', 'it', 'a', '2', 'is', 'because', 'some', 'of', 'the', 'places', 'they', 'are', 'at', 'look', "nice...that's", 'it.', 'and', 'the', 'reason', 'i', 'saw', 'it', 'was', 'because', 'we', 'went', 'to', 'the', 'sneak', 'preview', '(here', 'in', 'holland', 'we', 'have', 'a', 'strange', 'system', 'regarding', 'sneak', 'previews,', 'you', 'pay', 'less', 'money', 'then', 'for', 'a', 'regular', 'movie', 'and', 'you', "don't", 'know', 'what', 'movie', 'it', 'is', 'that', 'you', 'will', 'be', 'watching.', 'all', 'you', 'know', 'is', 'that', "it's", 'a', 'new', 'movie', "that's", 'not', 'yet', 'in', 'the', 'theaters).', 'my', 'advice', 'is', 'to', 'stay', 'far', 'away', 'from', 'this', 'film,', 'if', 'you', 'really', 'want', 'to', 'see', 'a', 'good', 'dutch', 'movie', 'watch', 'temmink', 'or', 'zwartboek.'], 'label': '0'}

# %%
print(train_data.fields.items())
# Out:
# dict_items([('text', <torchtext.data.field.Field object at 0x000001D964BC1860>), ('label', <torchtext.data.field.Field object at 0x000001D964BC12E8>)])

# %%
TEXT.build_vocab(train_data, min_freq=10, max_size=10000)

# %%
print('단어 집합의 크기 : {}'.format(len(TEXT.vocab)))
# Out:
# 단어 집합의 크기 : 10002

# %%
print(TEXT.vocab.stoi)
# Out:
# defaultdict(<bound method Vocab._default_unk_index of <torchtext.vocab.Vocab object at 0x000001D9825724E0>>, {'<unk>': 0, '<pad>': 1, 'the': 2, 'a': 3, 'and': 4, 'of': 5, 'to': 6, 'is': 7, 'in': 8, 'i': 9, 'this': 10, 'it': 11, 'that': 12, '/><br': 13, 'was': 14, 'as': 15, 'with': 16, 'for': 17, 'but': 18, 'on': 19, 'movie': 20, 'are': 21, 'not': 22, 'his': 23, 'you': 24, 'have': 25, 'film': 26, 'he': 27, 'be': 28, 'at': 29, 'one': 30, 'by': 31, 'an': 32, 'they': 33, 'from': 34, 'all': 35, 'who': 36, 'like': 37, 'so': 38, 'just': 39, 'or': 40, 'has': 41, 'about': 42, "it's": 43, 'her': 44, 'if': 45, 'some': 46, 'out': 47, 'what': 48, 'when': 49, 'very': 50, 'there': 51, 'more': 52, 'even': 53, 'would': 54, 'good': 55, 'she': 56, 'my': 57, 'only': 58, 'their': 59, 'no': 60, 'really': 61, 'had': 62, 'up': 63, 'which': 64, 'can': 65, 'were': 66, 'see': 67, 'than': 68, 'we': 69, 'been': 70, '-': 71, 'get': 72, 'into': 73, 'will': 74, 'much': 75, 'because': 76, 'how': 77, 'story': 78, 'most': 79, 'other': 80, "don't": 81, 'do': 82, 'great': 83, 'also': 84, 'me': 85, 'its': 86, 'time': 87, 'first': 88, 'make': 89, 'could': 90, 'people': 91, '/>the': 92, 'any': 93, 'after': 94, 'then': 95, 'bad': 96, 'made': 97, 'think': 98, 'many': 99, 'being': 100, 'never': 101, 'him': 102, '<br': 103, 'little': 104, 'two': 105, 'too': 106, 'where': 107, 'well': 108, 'way': 109, 'your': 110, 'it.': 111, 'watch': 112, 'did': 113, 'them': 114, 'movie.': 115, 'seen': 116, 'does': 117, 'best': 118, 'characters': 119, 'know': 120, 'love': 121, 'these': 122, 'character': 123, 'ever': 124, 'movies': 125, 'still': 126, 'films': 127, 'over': 128, 'such': 129, 'plot': 130, 'should': 131, 'acting': 132, 'those': 133, 'off': 134, 'show': 135, 'while': 136, 'film.': 137, 'better': 138, 'go': 139, "doesn't": 140, 'something': 141, 'through': 142, 'say': 143, 'why': 144, "didn't": 145, "i'm": 146, 'back': 147, 'scene': 148, 'movie,': 149, 'watching': 150, 'makes': 151, 'film,': 152, 'real': 153, 'find': 154, 'actually': 155, 'every': 156, 'scenes': 157, 'man': 158, 'few': 159, 'going': 160, 'nothing': 161, 'life': 162, 'new': 163, '/>i': 164, 'another': 165, 'same': 166, 'lot': 167, 'look': 168, '&': 169, 'thing': 170, 'pretty': 171, 'quite': 172, 'old': 173, 'want': 174, 'end': 175, 'seems': 176, "can't": 177, 'got': 178, 'before': 179, 'take': 180, 'actors': 181, 'part': 182, 'years': 183, 'give': 184, 'may': 185, 'us': 186, "that's": 187, 'thought': 188, 'young': 189, 'between': 190, 'big': 191, 'both': 192, 'without': 193, 'saw': 194, 'almost': 195, "isn't": 196, "i've": 197, 'gets': 198, 'around': 199, 'it,': 200, 'things': 201, 'here': 202, 'though': 203, 'director': 204, 'must': 205, 'horror': 206, 'now': 207, 'down': 208, 'whole': 209, 'come': 210, 'own': 211, '"the': 212, 'always': 213, "there's": 214, 'might': 215, 'work': 216, 'cast': 217, 'bit': 218, 'enough': 219, 'least': 220, 'am': 221, 'probably': 222, "he's": 223, 'since': 224, 'feel': 225, 'far': 226, 'last': 227, 'long': 228, 'kind': 229, 'rather': 230, 'found': 231, 'funny': 232, 'each': 233, 'fact': 234, 'our': 235, 'original': 236, 'world': 237, 'guy': 238, 'anything': 239, 'interesting': 240, 'worst': 241, 'making': 242, 'believe': 243, 'having': 244, 'trying': 245, 'right': 246, 'done': 247, 'comes': 248, 'music': 249, 'however,': 250, 'action': 251, 'anyone': 252, 'goes': 253, 'point': 254, 'played': 255, 'main': 256, 'put': 257, 'hard': 258, '/>this': 259, 'worth': 260, 'looks': 261, 'role': 262, 'series': 263, 'looking': 264, 'yet': 265, 'tv': 266, 'especially': 267, 'takes': 268, 'watched': 269, 'three': 270, 'seem': 271, 'minutes': 272, 'sure': 273, 'during': 274, 'plays': 275, 'script': 276, 'performance': 277, 'someone': 278, "wasn't": 279, 'shows': 280, 'set': 281, 'family': 282, 'times': 283, 'maybe': 284, 'although': 285, 'different': 286, 'away': 287, 'comedy': 288, 'everything': 289, 'woman': 290, 'time.': 291, 'girl': 292, 'left': 293, 'once': 294, 'american': 295, 'play': 296 ...

# %%
from torchtext.data import Iterator

# %%
batch_size = 5

train_loader = Iterator(dataset=train_data, batch_size = batch_size, device='cuda')
test_loader = Iterator(dataset=test_data, batch_size = batch_size,  device='cuda')

# %%
batch = next(iter(train_loader)) # 첫번째 미니배치

# %%
print(batch.text)
# Out:
# tensor([[  10,   26,    7,   42,    3, 2624,  345,  245,    6,  154,    0,    8,
#           757,  267,  121,   64,   27,   41,   22,   62,    3, 1734,    5,   17,
#           803, 5193,   13,  514,  733,    7,    3,   26, 1938,    3,  158,   16,
#            50,  341, 1120,    0,    4,   27,  577,  511,  201,   35,    2,  291,
#             2,  130,    7, 6263,    4,    0,    2,  256,  866,    0,    7,    0,
#            18,   10,  871,    5, 8219,    7,   22,    0,    0,   11,    7,   52,
#            37,   32, 2198, 3303,   64,   80, 5562,    0, 4579, 6205,    4, 2834,
#            94,  100, 6940,   21,    0,   51,    7,    3,  619,  495,    5, 1527,
#             8,    2,  775,   13,  514,    7,   22,  232,   15,    3,  288, 1313,
#            51,   21,   46,  232,   30, 6961,   18,   12,    7,  111,   11, 1327,
#             2,  753,    4, 7981,  996,    6,    0,   91,   16,  753, 7068,    9,
#            81,  154, 1198,  174,  278,    6, 1955, 4659,    0,  799,    1,    1,
#             1,    1,    1,    1,    1,    1],
#         [ 204,  490,    0,    4,  345,  606,    0,  340,    0, 1962, 1006,    0,
#             7,    3, 1038, 2608,   12,  126,  176, 1768,    4,    0, 2024,   38,
#            43,    3, 3018,   12,    0,    0,   97,    3,  366,   87, 1605,  176,
#            38, 2994,   31,    0,    2,  249,    7, 7978,    4,    2,  392, 5675,
#             0,  979,   21,  207, 1321,    8,    0,    0,    5,    2,    0,    2,
#           237,    5,    0,  176, 3440, 3263, 7123,    0,  326,    2,   87,    2,
#            20,   14, 1674,   18,   43,  258,    6, 1869,    6, 1782, 1894,    0,
#             4,    2,  871,    5, 2130,    8, 2923, 7287,  176,    0,    8,   32,
#           831,    5,  124, 4216,    0,  392,    2, 1037,  481,    7,    2, 1448,
#           738,    0,   19,    2, 5039,   18, 9161,    0,  911,   43,    3, 6735,
#           277,   34,    0, 4730,  186,  104, 3083,   73,   23, 3309,   40,    0,
#             4,    3,    0,   26,  193,   75,    5,    3,  123,    7,  101,    3,
#            55,    0,    9, 1034, 1821,   18],
#         [   8,    3, 1308,    0,    3,  238,    7,  568,   31, 1896,   16,    3,
#             0,   23, 1356,    0,    0,    0, 2070,  102,    4,  428,    6, 3960,
#          6211,  420,    0,    3,  396,  381,  420,  815,   41,    3,  163, 1959,
#           690, 7900,    0,    0,    4,    7,   42,    6, 1106, 4874, 1215,   16,
#          7900,    4,  657,   80, 3463,  421,    8,    3, 4988,  331,    0,    8,
#             0, 3048,    2,  579, 5021,   63, 2055,   60,    0,    4,  477,  811,
#          3333,   13,    0, 1263,    0,    0,  660,    5,   77,   22,    6,   82,
#             3, 2113,  206,  115,   17,    0, 1090,    0,    5,   10,   26,   21,
#          2191, 6662,    5,  122, 1611, 5267,    0, 4092,  244,    0, 9506,  301,
#            68,    2,    0,  336, 8810,  132,  441, 3356,  982,   84,   51,    7,
#            60, 1421,    8,  202,   29,  504,  146,   22,  652,    3,  206,   26,
#           687, 1421,   18,  239,    6,    0,   10,   63,   54,   25,    0,  627,
#             5,    2, 3145,   21,   61,  567],
#         [   2,  481,   16,   80,  181,  217,    8,    2,    0,    5,    0, 4363,
#             7,   12,   33,  447,  508,  106,  173,   17,    2,  182,    0,    0,
#             0,    0, 6266,    0,  624,    0, 1266,    0,   40,   12,   33,   66,
#          1980,    6, 1401,  134,    2,  686,    0, 1995,  193,  100,    0,    0,
#             7,    2,    0,    0,  819,    0,   35,    0, 3092,    4,    0,    0,
#            15, 2286,   31,    0,   38,    2, 3753,    7, 1371,   32,  345,   12,
#            41,    2,    0,    4, 2272,   17,    2,  182,    0,   36,   65, 2176,
#             2,    0,    0,    4,    0,   18,   29,    2,  166,   87,  261,   37,
#           278,    8,   23,  519,    0,    4,  812,    0, 2386,   11,   35,  134,
#             8,   10,  344,  659,  266,    0,   13,    0,   15, 1807,    0,  136,
#          6316,  998,   68,   48,    0,   62,    8, 2337,  117, 3898,   16,   23,
#             0,    0,   25,  101, 2731,   38, 1420,    4,    0,  267,  747, 9067,
#             8,    2, 9706,  334,   14,  171],
#         [  10,   26,   54,  575,    0,   15,    2,  241,   20,  397, 1381, 1381,
#            18,    8,   57, 1192,   11,    7,  802,    2,    0,    2, 6101,  591,
#             4, 1060,  151,   10,   26,    0,    9, 1150,    2,   20, 1872,    0,
#           142,    2, 7849, 8476,   29,   57,  605, 8086,    0,   85,    4,   46,
#           421,   95,  269,  200, 5654, 1872,  230,    0,   11,  553, 6684,   12,
#            10,  279,   93, 1519,  137,  348,    3, 9055,    0,    5,   48,   74,
#           222,   28,  638,    0,  227,  137,   29,   88,   69,   66, 1683,    4,
#            66, 2511,   17,    2,  317, 2449,    6,   28,  592,  134,   18, 4156,
#             8,  235,    0, 1214, 4951,   90,   28,    0,  348,   69,  269,    2,
#            26,  246, 1979,   29,    2,  175,   69,  553, 5222,   69,   62,  231,
#            93,    0, 6563,  141,   12,   24,   65,    0,  510,   29,   17, 4583,
#          1872, 1203,   17,   35,    2,  511, 3914,   69,  553, 1126,   35,  235,
#            80,  421,    4,   33,  106,    0]], device='cuda:0')

# %%
print(batch.text[0])
# Out:
# tensor([  10,   26,    7,   42,    3, 2624,  345,  245,    6,  154,    0,    8,
#          757,  267,  121,   64,   27,   41,   22,   62,    3, 1734,    5,   17,
#          803, 5193,   13,  514,  733,    7,    3,   26, 1938,    3,  158,   16,
#           50,  341, 1120,    0,    4,   27,  577,  511,  201,   35,    2,  291,
#            2,  130,    7, 6263,    4,    0,    2,  256,  866,    0,    7,    0,
#           18,   10,  871,    5, 8219,    7,   22,    0,    0,   11,    7,   52,
#           37,   32, 2198, 3303,   64,   80, 5562,    0, 4579, 6205,    4, 2834,
#           94,  100, 6940,   21,    0,   51,    7,    3,  619,  495,    5, 1527,
#            8,    2,  775,   13,  514,    7,   22,  232,   15,    3,  288, 1313,
#           51,   21,   46,  232,   30, 6961,   18,   12,    7,  111,   11, 1327,
#            2,  753,    4, 7981,  996,    6,    0,   91,   16,  753, 7068,    9,
#           81,  154, 1198,  174,  278,    6, 1955, 4659,    0,  799,    1,    1,
#            1,    1,    1,    1,    1,    1], device='cuda:0')
